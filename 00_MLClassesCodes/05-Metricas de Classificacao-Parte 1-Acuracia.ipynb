# %%
import numpy as np
from sklearn import metrics

# %% [markdown]
# ## Nossos rótulos com classes

# %%
y_true = np.array(['dog', 'dog', 'dog', 'dog', 'dog', 'dog',
    'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat',      
     'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit',
     'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit'])

y_pred = np.array(['dog', 'dog', 'dog', 'rabbit', 'cat', 'cat',
     'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 
     'dog', 'dog', 'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit',
     'rabbit', 'rabbit', 'rabbit', 'rabbit', 'rabbit'])

# %% [markdown]
# ## Cálculo da Acurácia usando o NumPy

# %%
np.sum(y_true == y_pred) / y_true.shape[0]
# Out:
# 0.7037037037037037

# %% [markdown]
# ## Cálculo da Acurácia usando o Scikit Learn

# %%
metrics.accuracy_score(y_true, y_pred)
# Out:
# 0.7037037037037037
